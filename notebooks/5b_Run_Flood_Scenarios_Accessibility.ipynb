# %% [markdown]
# <div style="
#     border-left: 6px solid #1f6feb;
#     padding: 0.7em 1em;
#     background: #f0f7ff;
#     border-radius: 4px;
#     margin: 1em 0;
#     font-size: 1.05em;
#     color: #0a0a0a;
# ">
#   <strong>📝 Note:</strong> The flood scenario analysis has not been implemented as notebook due to its long runtime. Please execute script 5b_Flood_Scenarios_Accessibility.py to proceed with the workflow.
# </div>
